# %% [markdown]
# # The Analyzer

# %%
# Libraries
import folium
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import data

# %%
# Import data from csv to pandas data frame
df_raw = pd.read_csv('wine_data.csv', 
                 sep=',', 
                 encoding='utf-8')
df_raw.head()
# Out:
#    typ                                          wein_name     land    region  \
# 0  rot  Apothic Inferno Red Blend Wine with a Whiskey ...      USA       NaN
# 1  rot                  Apothic Dark California Red Blend      USA       NaN
# 2  rot  Antonini Monte Chiara Montepulciano d'Abruzzo DOC  Italien  Abruzzen
# 3  rot                        Angelin Langhe Nebbiolo DOC  Italien   Piemont
# 4  rot    Amarone della Valpolicella DOCG Vigne Alte Zeni  Italien  Venetien
#
#               produzent        rebsorte  bewertung  alkohol  inhalt_cl  \
# 0  E. & J. Gallo Winery             NaN        4.0     16.0       75.0
# 1                   NaN  diverse Sorten        5.0     14.0       75.0
# 2         Montepulciano             NaN        4.0     12.5       75.0
# 3          Angelo Negro        Nebbiolo        0.0     14.0       75.0
# 4          Cantina Zeni        Molinara        5.0     15.5       75.0
#
#    anzahl_fl  jahrgang  prime_start  prime_end  preis_chf  preis_cl  \
# 0          1      2018         2022       2023      19.95      0.27
# 1          1      2016         2022       2024      12.95      0.17
# 2          1      2020         2023       2024       3.75      0.05
# 3          1      2021         2022       2026      17.50      0.23
# 4          1      2019         2024       2028      32.95      0.44
#
#          lat         lon
# 0  39.783730 -100.445882
# 1  39.783730 -100.445882
# 2  42.638426   12.674297
# 3  42.638426   12.674297
# 4  42.638426   12.674297

# %% [markdown]
# ## Compare wine type to price

# %% [markdown]
# ## Adding geolocations for all production countries / regions

# %% [markdown]
# ### Preparing data from csv to plot to map

# %%
# Read the data to a pandas data frame
df1 = df_raw[['land', 'lat', 'lon']]

# Preparing data, so it doesn't plot duplicate values more than once
df2 = df1.drop_duplicates()
df3 = df2.reset_index(drop=True)
df3.head()
# Out:
#           land        lat         lon
# 0          USA  39.783730 -100.445882
# 1      Italien  42.638426   12.674297
# 2  Argentinien -34.996496  -64.967282
# 3   Frankreich  46.603354    1.888334
# 4        Chile -31.761336  -71.318770

# %% [markdown]
# ### Plotting the map

# %%
# Initalises the map
m = folium.Map(location=[47.44, 8.65], zoom_start=10)

# Add lat/lon of addresses
for i in range(0, len(df3)):
    folium.Marker(location=(df3.iloc[i]['lat'], 
                            df3.iloc[i]['lon']), 
                  popup=df3.iloc[i]['land']).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26a6103544fdd747cfc5945306439dda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26a6103544fdd747cfc5945306439dda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26a6103544fdd747cfc5945306439dda = L.map(
#                 &quot;map_26a6103544fdd747cfc5945306439dda&quot;,
#                 {
#                     center: [47.44, 8.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f0a9199e5c23c54fabc09b34b8d3d36 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26a6103544fdd747cfc5945306439dda);
#
#
#             var marker_e7d55a2d929e35ff7916ed3b11a967e3 = L.marker(
#                 [39.7837304, -100.445882],
#                 {}
#             ).addTo(map_26a6103544fdd747cfc5945306439dda);
#
#
#         var popup_af1273ae44ea0ed7ff21cb867eeff7b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4cf7787db5a43390707dfdbb0f8a818e = $(`&lt;div id=&quot;html_4cf7787db5a43390707dfdbb0f8a818e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;USA&lt;/div&gt;`)[0];
#                 popup_af1273ae44ea0ed7ff21cb867eeff7b0.setContent(html_4cf7787db5a43390707dfdbb0f8a818e);
#
#
#
#         marker_e7d55a2d929e35ff7916ed3b11a967e3.bindPopup(popup_af1273ae44ea0ed7ff21cb867eeff7b0)
#         ;
#
#
#
#
#             var marker_b0c9ace2b813a769116aae6c384516f0 = L.marker(
#                 [42.6384261, 12.674297],
#                 {}
#             ).addTo(map_26a6103544fdd747cfc5945306439dda);
#
#
#         var popup_f86710085aa4384c9f20158588c26c0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e49ec9528c9c355d94d5c958bb0fe8f8 = $(`&lt;div id=&quot;html_e49ec9528c9c355d94d5c958bb0fe8f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Italien&lt;/div&gt;`)[0];
#                 popup_f86710085aa4384c9f20158588c26c0b.setContent(html_e49ec9528c9c355d94d5c958bb0fe8f8);
#
#
#
#         marker_b0c9ace2b813a769116aae6c384516f0.bindPopup(popup_f86710085aa4384c9f20158588c26c0b)
#         ;
#
#
#
#
#             var marker_a5eb465c996c9bf5c0479c3edef5a310 = L.marker(
#                 [-34.9964963, -64.9672817],
#                 {}
#             ).addTo(map_26a6103544fdd747cfc5945306439dda);
#
#
#         var popup_0e406314ea900a5ed246ceeaa4e59a35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4918065e92f35494788602086a8bbe0 = $(`&lt;div id=&quot;html_b4918065e92f35494788602086a8bbe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Argentinien&lt;/div&gt;`)[0];
#                 popup_0e406314ea900a5ed246ceeaa4e59a35.setContent(html_b4918065e92f35494788602086a8bbe0);
#
#
#
#         marker_a5eb465c996c9bf5c0479c3edef5a310.bindPopup(popup_0e406314ea900a5ed246ceeaa4e59a35)
#         ;
#
#
#
#
#             var marker_57e26802aad05b0474024fc3c046aa9a = L.marker(
#                 [46.603354, 1.8883335],
#                 {}
#             ).addTo(map_26a6103544fdd747cfc5945306439dda);
#
#
#         var popup_045869353b21dacc2e55715969077f53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5caceb61c5fcfe0b50b734e9969a4b48 = $(`&lt;div id=&quot;html_5caceb61c5fcfe0b50b734e9969a4b48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Frankreich&lt;/div&gt;`)[0];
#                 popup_045869353b21dacc2e55715969077f53.setContent(html_5caceb61c5fcfe0b50b734e9969a4b48);
#
#
#
#         marker_57e26802aad05b0474024fc3c046aa9a.bindPopup(popup_045869353b21dacc2e55715969077f53)
#         ;
#
#
#
#
#             var marker_13e046b301bc699424db5ba39b24b29b = L.marker(
#                 [-31.7613365, -71.3187697],
#                 {}
#             ).addTo(map_26a6103544fdd747cfc5945306439dda);
#
#
#         var popup_701d6cd9df376c7ed50d4357dae98643 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1447845e9c278c2122921e22fa306bbf = $(`&lt;div id=&quot;html_1447845e9c278c2122921e22fa306bbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chile&lt;/div&gt;`)[0];
#                 popup_701d6cd9df376c7ed50d4357dae98643.setContent(html_1447845e9c278c2122921e22fa306bbf);
#
#
#
#         marker_13e046b301bc699424db5ba39b24b29b.bindPopup(popup_701d6cd9df376c7ed50d4357dae98643)
#         ;
#
#
#
#
#             var marker_cd2d51d12dd5321adf104055123d8775 = L.marker(
#                 [39.6621648, -8.1353519],
#                 {}
#             ).addTo(map_26a6103544fdd747cfc5945306439dda);
#
#
#         var popup_0f828384261ac9ed8576a97fcdb663b6 = L.popup({&quot;ma
